# %% [markdown]
# # Zero Shot Text Classification

# %%
import pandas as pd
import numpy as np
books = pd.read_csv("./ds/cleaned_data.csv")

# %%
from transformers import pipeline
from typing import List

classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli", device="cuda")
# Out:
# Device set to use cuda
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 4
#       1 from transformers import pipeline
#       2 from typing import List
# ----> 4 classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli", device="cuda")
#
# File ~/dlytica/internship/recommendation-system/env/lib/python3.12/site-packages/transformers/pipelines/__init__.py:1180, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1177 if processor is not None:
#    1178     kwargs["processor"] = processor
# -> 1180 return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# File ~/dlytica/internship/recommendation-system/env/lib/python3.12/site-packages/transformers/pipelines/zero_shot_classification.py:89, in ZeroShotClassificationPipeline.__init__(self, args_parser, *args, **kwargs)
#      87 def __init__(self, args_parser=ZeroShotClassificationArgumentHandler(), *args, **kwargs):
#      88     self._args_parser = args_parser
# ---> 89     super().__init__(*args, **kwargs)
#      90     if self.entailment_id == -1:
#      91         logger.warning(
#      92             "Failed to determine 'entailment' label id from the label2id mapping in the model config. Setting to "
#      93             "-1. Define a descriptive label2id mapping in the model config to ensure correct outputs."
#      94         )
#
# File ~/dlytica/internship/recommendation-system/env/lib/python3.12/site-packages/transformers/pipelines/base.py:1016, in Pipeline.__init__(self, model, tokenizer, feature_extractor, image_processor, processor, modelcard, framework, task, args_parser, device, torch_dtype, binary_output, **kwargs)
#    1009 # We shouldn't call `model.to()` for models loaded with accelerate as well as the case that model is already on device
#    1010 if (
#    1011     self.framework == "pt"
#    1012     and self.model.device != self.device
#    1013     and not (isinstance(self.device, int) and self.device < 0)
#    1014     and hf_device_map is None
#    1015 ):
# -> 1016     self.model.to(self.device)
#    1018 # If it's a generation pipeline and the model can generate:
#    1019 # 1 - create a local generation config. This is done to avoid side-effects on the model as we apply local
#    1020 # tweaks to the generation config.
#    1021 # 2 - load the assistant model if it is passed.
#    1022 if self._pipeline_calls_generate and self.model.can_generate():
#
# File ~/dlytica/internship/recommendation-system/env/lib/python3.12/site-packages/transformers/modeling_utils.py:3851, in PreTrainedModel.to(self, *args, **kwargs)
#    3846     if dtype_present_in_args:
#    3847         raise ValueError(
#    3848             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    3849             " `dtype` by passing the correct `torch_dtype` argument."
#    3850         )
# -> 3851 return super().to(*args, **kwargs)
#
# File ~/dlytica/internship/recommendation-system/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1355, in Module.to(self, *args, **kwargs)
#    1352         else:
#    1353             raise
# -> 1355 return self._apply(convert)
#
# File ~/dlytica/internship/recommendation-system/env/lib/python3.12/site-packages/torch/nn/modules/module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
# File ~/dlytica/internship/recommendation-system/env/lib/python3.12/site-packages/torch/nn/modules/module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 915 (3 times)]
#
# File ~/dlytica/internship/recommendation-system/env/lib/python3.12/site-packages/torch/nn/modules/module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
# File ~/dlytica/internship/recommendation-system/env/lib/python3.12/site-packages/torch/nn/modules/module.py:942, in Module._apply(self, fn, recurse)
#     938 # Tensors stored in modules are graph leaves, and we don't want to
#     939 # track autograd history of `param_applied`, so we have to use
#     940 # `with torch.no_grad():`
#     941 with torch.no_grad():
# --> 942     param_applied = fn(param)
#     943 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     945 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/dlytica/internship/recommendation-system/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1341, in Module.to.<locals>.convert(t)
#    1334     if convert_to_format is not None and t.dim() in (4, 5):
#    1335         return t.to(
#    1336             device,
#    1337             dtype if t.is_floating_point() or t.is_complex() else None,
#    1338             non_blocking,
#    1339             memory_format=convert_to_format,
#    1340         )
# -> 1341     return t.to(
#    1342         device,
#    1343         dtype if t.is_floating_point() or t.is_complex() else None,
#    1344         non_blocking,
#    1345     )
#    1346 except NotImplementedError as e:
#    1347     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# KeyboardInterrupt:

# %% [markdown]
# ### Manually map top categories into Fiction or Non Fiction to establish a basis

# %%
category_mapping = {'Fiction' : "Fiction",
 'Juvenile Fiction': "Children's Fiction",
 'Biography & Autobiography': "Nonfiction",
 'History': "Nonfiction",
 'Literary Criticism': "Nonfiction",
 'Philosophy': "Nonfiction",
 'Religion': "Nonfiction",
 'Comics & Graphic Novels': "Fiction",
 'Drama': "Fiction",
 'Juvenile Nonfiction': "Children's Nonfiction",
 'Science': "Nonfiction",
 'Poetry': "Fiction"}

books["simplified_category"] = books["categories"].map(category_mapping)
books["simplified_category"]
# Out:
# 0          Fiction
# 1              NaN
# 2          Fiction
# 3              NaN
# 4              NaN
#            ...
# 5688           NaN
# 5689           NaN
# 5690    Nonfiction
# 5691    Nonfiction
# 5692    Nonfiction
# Name: simplified_category, Length: 5693, dtype: object

# %% [markdown]
# > we don't have enough samples in our dataset to check if the model would correctly classify for classes with other niche labels like "romance". etc.
#
# > We could make the model make predictions for more classes, but we wouldnt be able to verify if those predictions would be right.
#
# > however, we have enough Fiction, Nonfiction samples. so we can verify (by calculating accuracy) with those samples and if proven to be accourate enough, we can use the model to make predictions for those classes.
#
# > we could also assume that the classifier is apt enough to classify the niche descriptions, but that would be risky.
#
# > still, I'm keeping childrens fiction and childrens nonfiction as possible class

# %%
category_classes = ["Fiction", "Nonfiction", "Children's Fiction", "Children's Nonfiction"]

# %%
sample_text = "a book about startups run by school children. it has stories of little founders of 500 companies registered in the USA from 2010 to 2025. Motivates kids by acquainting them with children of their age. aimed at children"
sample_text = books.iloc[0]["description"]

# %% [markdown]
# ### Continue classification

# %%
# eg:
max_index = np.argmax(classifier(sample_text, category_classes)["scores"])
label_or_category = classifier(sample_text, category_classes)["labels"][max_index]
label_or_category
# Out:
# 'Fiction'

# %%
from typing import List
def classify_text(text: str, labels: List[str] = category_classes):
    
    # print(result["labels"])
    # print(result["scores"])
    
    #found that the labels and scores are sorted in descending order automatically. So, we can simply use the 0th index instead of argmax and use that index as in the above cell
    return classifier(text,labels)["labels"][0]

# %%
text = "a book about the king of london, king charles and queen elizabeth. Case study of how they run politics and the country"
classify_text(text)
# Out:
# 'Nonfiction'

# %% [markdown]
# > Now that we have our classifier function ready, we can go on and check the accuracy of the classifications to see if it is usable

# %%
from tqdm.notebook import tqdm

#expects a series of descriptio, all of the same category (actual_category)
def get_classification_accuracy( description_series: List[str], actual_category: str):
    correct_prediction = 0

    for description in tqdm(description_series):
        
        predicted_category = classify_text(description)
        
        if predicted_category == actual_category:
            correct_prediction +=1
    
    return correct_prediction/len(description_series)

# %%
books.columns
# Out:
# Index(['isbn13', 'isbn10', 'title', 'authors', 'categories', 'thumbnail',
#        'description', 'published_year', 'average_rating', 'num_pages',
#        'ratings_count', 'title_and_subtitle', 'tagged_description',
#        'simplified_category'],
#       dtype='object')

# %%
n= 300

fiction_series = books.loc[books["simplified_category"] == "Fiction", "description"][:n]
nonfiction_series = books.loc[books["simplified_category"] == "Nonfiction", "description"][:n]

# %%
get_classification_accuracy(fiction_series, "Fiction")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# 0.6566666666666666

# %%
get_classification_accuracy(nonfiction_series, "Nonfiction")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# 0.87

# %% [markdown]
# > Not very good accuracies but I'm going with the classifier anyways

# %% [markdown]
# ### Finding categories for the records with NaN in categories field.

# %%
records_with_nan_category = books.loc[books["simplified_category"].isna(), ["isbn13", "description"]].reset_index(drop=True)
records_with_nan_category
# Out:
#              isbn13                                        description
# 0     9780002261982  A new 'Christie for Christmas' -- a full-lengt...
# 1     9780006280897  Lewis' work on the nature of love divides love...
# 2     9780006280934  "In The Problem of Pain, C.S. Lewis, one of th...
# 3     9780006380832  Until Vasco da Gama discovered the sea-route t...
# 4     9780006470229  A new-cover reissue of the fourth book in the ...
# ...             ...                                                ...
# 1571  9788125026600  Not only does Nietzsche for Beginners delve in...
# 1572  9788171565641  Forster's lively, informed originality and wit...
# 1573  9788172235222  On A Train Journey Home To North India After L...
# 1574  9788173031014  This book tells the tale of a man who goes on ...
# 1575  9788179921623  Wisdom to Create a Life of Passion, Purpose, a...
#
# [1576 rows x 2 columns]

# %%
records_with_nan_category["predicted_category"] = records_with_nan_category["description"].apply(classify_text)
records_with_nan_category
# Out:
#              isbn13                                        description  \
# 0     9780002261982  A new 'Christie for Christmas' -- a full-lengt...
# 1     9780006280897  Lewis' work on the nature of love divides love...
# 2     9780006280934  "In The Problem of Pain, C.S. Lewis, one of th...
# 3     9780006380832  Until Vasco da Gama discovered the sea-route t...
# 4     9780006470229  A new-cover reissue of the fourth book in the ...
# ...             ...                                                ...
# 1571  9788125026600  Not only does Nietzsche for Beginners delve in...
# 1572  9788171565641  Forster's lively, informed originality and wit...
# 1573  9788172235222  On A Train Journey Home To North India After L...
# 1574  9788173031014  This book tells the tale of a man who goes on ...
# 1575  9788179921623  Wisdom to Create a Life of Passion, Purpose, a...
#
#      predicted_category
# 0               Fiction
# 1            Nonfiction
# 2            Nonfiction
# 3            Nonfiction
# 4               Fiction
# ...                 ...
# 1571         Nonfiction
# 1572            Fiction
# 1573            Fiction
# 1574         Nonfiction
# 1575            Fiction
#
# [1576 rows x 3 columns]

# %%
books = pd.merge(books, records_with_nan_category[["isbn13","predicted_category"]], on="isbn13", how="left")

# %% [markdown]
# > this will cause the books df to have a predicted_category column.
# > we want the values from predicted_category to be in simplified_category whenever there are null values in simplified_category

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5688  9788173031014  8173031010
# 5689  9788179921623  817992162X
# 5690  9788185300535  8185300534
# 5691  9789027712059  9027712050
# 5692  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5688                                Journey to the East
# 5689  The Monk Who Sold His Ferrari: A Fable About F...
# 5690                                          I Am that
# 5691                           The Berlin Phenomenology
# 5692                          'I'm Telling You Stories'
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5688                                 Hermann Hesse
# 5689                                  Robin Sharma
# 5690  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5691                 Georg Wilhelm Friedrich Hegel
# 5692                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5688              Adventure stories
# 5689               Health & Fitness
# 5690                     Philosophy
# 5691                        History
# 5692             Literary Criticism
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5688  http://books.google.com/books/content?id=rq6JP...
# 5689  http://books.google.com/books/content?id=c_7mf...
# 5690  http://books.google.com/books/content?id=Fv_JP...
# 5691  http://books.google.com/books/content?id=Vy7Sk...
# 5692  http://books.google.com/books/content?id=2lVyR...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5688  This book tells the tale of a man who goes on ...          2002.0
# 5689  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5690  This collection of the timeless teachings of o...          1999.0
# 5691  Since the three volume edition ofHegel's Philo...          1981.0
# 5692  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5688            3.70      175.0           24.0
# 5689            3.82      198.0         1568.0
# 5690            4.51      531.0          104.0
# 5691            0.00      210.0            0.0
# 5692            3.70      136.0           10.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5688                                Journey to the East
# 5689  The Monk Who Sold His Ferrari: A Fable About F...
# 5690     I Am that: Talks with Sri Nisargadatta Maharaj
# 5691                           The Berlin Phenomenology
# 5692  'I'm Telling You Stories': Jeanette Winterson ...
#
#                                      tagged_description simplified_category  \
# 0     9780002005883 A NOVEL THAT READERS and critics...             Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...                 NaN
# 2     9780006178736 A memorable, mesmerizing heroine...             Fiction
# 3     9780006280897 Lewis' work on the nature of lov...                 NaN
# 4     9780006280934 "In The Problem of Pain, C.S. Le...                 NaN
# ...                                                 ...                 ...
# 5688  9788173031014 This book tells the tale of a ma...                 NaN
# 5689  9788179921623 Wisdom to Create a Life of Passi...                 NaN
# 5690  9788185300535 This collection of the timeless ...          Nonfiction
# 5691  9789027712059 Since the three volume edition o...          Nonfiction
# 5692  9789042003408 This is a jubilant and rewarding...          Nonfiction
#
#      predicted_category
# 0                   NaN
# 1               Fiction
# 2                   NaN
# 3            Nonfiction
# 4            Nonfiction
# ...                 ...
# 5688         Nonfiction
# 5689            Fiction
# 5690                NaN
# 5691                NaN
# 5692                NaN
#
# [5693 rows x 15 columns]

# %%
books["simplified_category"] = books["simplified_category"].fillna(books["predicted_category"])
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5688  9788173031014  8173031010
# 5689  9788179921623  817992162X
# 5690  9788185300535  8185300534
# 5691  9789027712059  9027712050
# 5692  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5688                                Journey to the East
# 5689  The Monk Who Sold His Ferrari: A Fable About F...
# 5690                                          I Am that
# 5691                           The Berlin Phenomenology
# 5692                          'I'm Telling You Stories'
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5688                                 Hermann Hesse
# 5689                                  Robin Sharma
# 5690  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5691                 Georg Wilhelm Friedrich Hegel
# 5692                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5688              Adventure stories
# 5689               Health & Fitness
# 5690                     Philosophy
# 5691                        History
# 5692             Literary Criticism
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5688  http://books.google.com/books/content?id=rq6JP...
# 5689  http://books.google.com/books/content?id=c_7mf...
# 5690  http://books.google.com/books/content?id=Fv_JP...
# 5691  http://books.google.com/books/content?id=Vy7Sk...
# 5692  http://books.google.com/books/content?id=2lVyR...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5688  This book tells the tale of a man who goes on ...          2002.0
# 5689  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5690  This collection of the timeless teachings of o...          1999.0
# 5691  Since the three volume edition ofHegel's Philo...          1981.0
# 5692  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5688            3.70      175.0           24.0
# 5689            3.82      198.0         1568.0
# 5690            4.51      531.0          104.0
# 5691            0.00      210.0            0.0
# 5692            3.70      136.0           10.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5688                                Journey to the East
# 5689  The Monk Who Sold His Ferrari: A Fable About F...
# 5690     I Am that: Talks with Sri Nisargadatta Maharaj
# 5691                           The Berlin Phenomenology
# 5692  'I'm Telling You Stories': Jeanette Winterson ...
#
#                                      tagged_description simplified_category  \
# 0     9780002005883 A NOVEL THAT READERS and critics...             Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...             Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...             Fiction
# 3     9780006280897 Lewis' work on the nature of lov...          Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...          Nonfiction
# ...                                                 ...                 ...
# 5688  9788173031014 This book tells the tale of a ma...          Nonfiction
# 5689  9788179921623 Wisdom to Create a Life of Passi...             Fiction
# 5690  9788185300535 This collection of the timeless ...          Nonfiction
# 5691  9789027712059 Since the three volume edition o...          Nonfiction
# 5692  9789042003408 This is a jubilant and rewarding...          Nonfiction
#
#      predicted_category
# 0                   NaN
# 1               Fiction
# 2                   NaN
# 3            Nonfiction
# 4            Nonfiction
# ...                 ...
# 5688         Nonfiction
# 5689            Fiction
# 5690                NaN
# 5691                NaN
# 5692                NaN
#
# [5693 rows x 15 columns]

# %%
books = books.drop(columns=["predicted_category"])

# %%
books["simplified_category"].isna().sum()
# Out:
# np.int64(0)

# %%
books["simplified_category"].unique()
# Out:
# array(['Fiction', 'Nonfiction', "Children's Fiction",
#        "Children's Nonfiction"], dtype=object)

# %% [markdown]
# > Now we have no nans and only 4 categories in total

# %%
books.to_csv("./ds/cleaned_data_2[category_fixed].csv")
